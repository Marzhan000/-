# %% [markdown]
# Осы аптадағы тәжірибелік зертханада сіз бір конфигурацияны қолданып көресіз және бұл желілердің көптеген түрлерінің тіркесімі: деректер терезелері конвульсиядан өтеді, одан кейін жинақталған LSTM, содан кейін жинақталған тығыз қабаттар.

# %% [markdown]
# ## Қажетті модульдерді импорттаңыз

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_series(x, y, format="-", start=0, end=None,
                title=None, xlabel=None, ylabel=None, legend=None ):
    """
    Уақыттық қатар деректерін визуалдау

    Параметрлер:
      x (бүтін сандар массиві) - x осіне арналған мәндерді қамтиды
      y (бүтін сандар массиві немесе массивтердің жұбы) - y осіне арналған мәндерді қамтиды
      format (жол) - график сызығының стилі
      start (бүтін сан) - графикте көрсетілетін бірінші уақыт қадамы
      end (бүтін сан) - графикте көрсетілетін соңғы уақыт қадамы
      title (жол) - графиктің тақырыбы
      xlabel (жол) - x осінің атауы
      ylabel (жол) - y осінің атауы
      legend (жолдар тізімі) - графиктің легендасы
    """

    # График фигурасының өлшемдерін орнату
    plt.figure(figsize=(10, 6))

    # Екіден көп қатарды графиктеу қажет пе екенін тексеру
    if type(y) is tuple:

      # y элементтері бойынша цикл жасау
      for y_curr in y:

        # x және ағымдағы y мәндерін графиктеу
        plt.plot(x[start:end], y_curr[start:end], format)

    else:
      # x және y мәндерін графиктеу
      plt.plot(x[start:end], y[start:end], format)

    # x осінің атауын белгілеу
    plt.xlabel(xlabel)

    # y осінің атауын белгілеу
    plt.ylabel(ylabel)

    # Легенданы орнату
    if legend:
      plt.legend(legend)

    # Тақырыпты орнату
    plt.title(title)

    # Графиктің үстіне тор сызбасын қосу
    plt.grid(True)

    # Экранда графикті көрсету
    plt.show()

# %% [markdown]
# ## Деректер жинағын жүктеп алыңыз және алдын ала қараңыз

# %%
# !wget -nc https://storage.googleapis.com/tensorflow-1-public/course4/Sunspots.csv
# Out:
# "wget" не является внутренней или внешней
# командой, исполняемой программой или пакетным файлом.

# %%
import requests

url = "https://www.kaggle.com/datasets/avinashmynampati/nvidia-stock-volatility-20142024"
response = requests.get(url)

with open("NVIDIA_Stock_Volatility_2014_2024.csv", "wb") as file:
    file.write(response.content)

print("Файл успешно скачан!")
# Out:
# Файл успешно скачан!

# %%
import pandas as pd

try:
    df = pd.read_csv('C:\Users\User\Downloads\NVIDIA_Stock_Volatility_2014_2024.csv', sep=None, engine='python')
    print(df.head())  # Алғашқы 5 жолды шығару
except Exception as e:
    print("Файлды оқу кезінде қате кетті:", e)
# Out:
#   Cell In[29], line 4
#     df = pd.read_csv('C:\Users\User\Downloads\NVIDIA_Stock_Volatility_2014_2024.csv', sep=None, engine='python')
#                                                                                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Путь к файлу
file_path = "C:/Users/User/Downloads/NVIDIA_Stock_Volatility_2014_2024.csv"


# Попытка загрузить CSV
try:
    df = pd.read_csv(file_path)
    print("Файл успешно загружен!")
    print("Первые строки файла:\n", df.head())
except Exception as e:
    print("Ошибка при чтении файла:", e)
    exit()

# Проверяем названия столбцов
print("Доступные столбцы:", df.columns)

# Пробуем использовать "Date" как время и "Close" как значения
try:
    df["Date"] = pd.to_datetime(df["Date"])  # Преобразуем дату в удобный формат
    time = np.array(df["Date"])
    series = np.array(df["Close"])
except KeyError as e:
    print(f"Ошибка: Не найден один из ключевых столбцов ({e})")
    exit()

# Функция для построения графика
def plot_series(time, series, xlabel="Time", ylabel="Value"):
    plt.figure(figsize=(10, 5))
    plt.plot(time, series, label="Stock Price", color="blue")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()
    plt.xticks(rotation=45)
    plt.show()

# Построение графика
plot_series(time, series, xlabel="Дата", ylabel="Цена акции")
# Out:
# Ошибка при чтении файла: Error tokenizing data. C error: Expected 1 fields in line 9, saw 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 19
#      16     exit()
#      18 # Проверяем названия столбцов
# ---> 19 print("Доступные столбцы:", df.columns)
#      21 # Пробуем использовать "Date" как время и "Close" как значения
#      22 try:
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Деректер жиынын бөліңіз

# %%
# Define the split time
split_time = 3000

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %% [markdown]
# ## Мүмкіндіктер мен белгілерді дайындаңыз

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Деректер жиынтығының терезелерін құрады

    Параметрлер:
      series (float сандар массиві) - уақыттық қатардың мәндерін қамтиды
      window_size (бүтін сан) - ерекшелікке енгізілетін уақыт қадамдарының саны
      batch_size (бүтін сан) - пакет көлемі
      shuffle_buffer (бүтін сан) - араластыру әдісі үшін қолданылатын буфер көлемі

    Қайтарады:
      dataset (TF Dataset) - уақыттық терезелерді қамтитын TF деректер жиынтығы
    """

    # RNN қабаттарының ерекшелік өлшемі үшін қосымша ось қосу
    series = tf.expand_dims(series, axis=-1)

    # Серия мәндерінен TF деректер жиынтығын жасау
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Деректерді терезеге бөлу, тек көрсетілген өлшемдегі терезелерді таңдау
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Терезелерді бір пакетке біріктіру арқылы тегістеу
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Ерекшеліктер мен белгілерді қамтитын кортеждерді жасау
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Терезелерді араластыру
    dataset = dataset.shuffle(shuffle_buffer)

    # Терезелердің пакеттерін жасау
    dataset = dataset.batch(batch_size)

    # Оқыту үшін деректер жиынтығын оңтайландыру
    dataset = dataset.cache().prefetch(1)

    return dataset

# %% [markdown]
# егер сіздің нәтижелеріңіз жақсы болмаса, мұнда параметрлерді өзгертуге және модельдің жақсырақ үйренетінін көруге болады.

# %%
# Параметрлер
window_size = 30
batch_size = 32
shuffle_buffer_size = 1000

# Деректер жиынының терезелерін жасаңыз
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# ## Үлгіні құрастыру

# %%
model = tf.keras.models.Sequential([
    tf.keras.Input(shape=(window_size,1)),
    tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal'),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(30, activation="relu"),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 400)
])

# Үлгінің қысқаша мазмұнын басып шығарыңыз
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:219: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 30, 64)         │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 30, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 30)             │         1,950 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           310 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,575 (267.87 KB)
#  Trainable params: 68,575 (267.87 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Оқу жылдамдығын реттеңіз
#
# оңтайлы оқу жылдамдығын таңдағыңыз келеді.

# %%
# Бастапқы салмақтарды алыңыз
init_weights = model.get_weights()

# %%
# Оқу жылдамдығын реттегішті орнату
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Оптимизаторды инициализациялау
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Оқыту параметрлерін орнату
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Модельді оқыту
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 15s 63ms/step - loss: 115.5888 - learning_rate: 1.0000e-08
# Epoch 2/100
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - loss: 88.0455
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 85.8220 - learning_rate: 1.1220e-08
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 67.5027 - learning_rate: 1.2589e-08
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 59.4932 - learning_rate: 1.4125e-08
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 54.3267 - learning_rate: 1.5849e-08
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 50.4013 - learning_rate: 1.7783e-08
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - loss: 47.3305 - learning_rate: 1.9953e-08
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 44.9642 - learning_rate: 2.2387e-08
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - loss: 43.0923 - learning_rate: 2.5119e-08
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 41.5554 - learning_rate: 2.8184e-08
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 40.2467 - learning_rate: 3.1623e-08
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 39.1294 - learning_rate: 3.5481e-08
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 38.1248 - learning_rate: 3.9811e-08
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 37.1329 - learning_rate: 4.4668e-08
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 36.1059 - learning_rate: 5.0119e-08
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 35.0803 - learning_rate: 5.6234e-08
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 34.0189 - learning_rate: 6.3096e-08
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 32.8502 - learning_rate: 7.0795e-08
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 31.6238 - learning_rate: 7.9433e-08
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 30.3488 - learning_rate: 8.9125e-08
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 29.0747 - learning_rate: 1.0000e-07
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 27.8182 - learning_rate: 1.1220e-07
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 26.4219 - learning_rate: 1.2589e-07
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 26.8462 - learning_rate: 1.4125e-07
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 25.3349 - learning_rate: 1.5849e-07
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 24.6336 - learning_rate: 1.7783e-07
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 23.7123 - learning_rate: 1.9953e-07
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 22.8447 - learning_rate: 2.2387e-07
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 22.0588 - learning_rate: 2.5119e-07
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 21.3695 - learning_rate: 2.8184e-07
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 20.9457 - learning_rate: 3.1623e-07
# Epoch 32/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 20.2920 - learning_rate: 3.5481e-07
# Epoch 33/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 19.8064 - learning_rate: 3.9811e-07
# Epoch 34/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 19.4556 - learning_rate: 4.4668e-07
# Epoch 35/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 19.2501 - learning_rate: 5.0119e-07
# Epoch 36/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 19.1684 - learning_rate: 5.6234e-07
# Epoch 37/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 19.0078 - learning_rate: 6.3096e-07
# Epoch 38/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 19.0912 - learning_rate: 7.0795e-07
# Epoch 39/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 19.1930 - learning_rate: 7.9433e-07
# Epoch 40/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 19.1022 - learning_rate: 8.9125e-07
# Epoch 41/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 18.9126 - learning_rate: 1.0000e-06
# Epoch 42/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 18.7290 - learning_rate: 1.1220e-06
# Epoch 43/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 19.7940 - learning_rate: 1.2589e-06
# Epoch 44/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 19.1506 - learning_rate: 1.4125e-06
# Epoch 45/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 19.9075 - learning_rate: 1.5849e-06
# Epoch 46/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 19.4901 - learning_rate: 1.7783e-06
# Epoch 47/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 20.7037 - learning_rate: 1.9953e-06
# Epoch 48/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 18.9235 - learning_rate: 2.2387e-06
# Epoch 49/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 19.7246 - learning_rate: 2.5119e-06
# Epoch 50/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 19.1099 - learning_rate: 2.8184e-06
# Epoch 51/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 18.9115 - learning_rate: 3.1623e-06
# Epoch 52/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 18.5799 - learning_rate: 3.5481e-06
# Epoch 53/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 18.7429 - learning_rate: 3.9811e-06
# Epoch 54/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 18.9190 - learning_rate: 4.4668e-06
# Epoch 55/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 18.7650 - learning_rate: 5.0119e-06
# Epoch 56/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 19.5120 - learning_rate: 5.6234e-06
# Epoch 57/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 18.9754 - learning_rate: 6.3096e-06
# Epoch 58/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 19.6932 - learning_rate: 7.0795e-06
# Epoch 59/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 18.7969 - learning_rate: 7.9433e-06
# Epoch 60/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 19.3072 - learning_rate: 8.9125e-06
# Epoch 61/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 21.8890 - learning_rate: 1.0000e-05
# Epoch 62/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 20.4017 - learning_rate: 1.1220e-05
# Epoch 63/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 19.9274 - learning_rate: 1.2589e-05
# Epoch 64/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 20.3174 - learning_rate: 1.4125e-05
# Epoch 65/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 20.7327 - learning_rate: 1.5849e-05
# Epoch 66/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 20.7257 - learning_rate: 1.7783e-05
# Epoch 67/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 20.6818 - learning_rate: 1.9953e-05
# Epoch 68/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 20.2505 - learning_rate: 2.2387e-05
# Epoch 69/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 20.4421 - learning_rate: 2.5119e-05
# Epoch 70/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 20.9637 - learning_rate: 2.8184e-05
# Epoch 71/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 19.2526 - learning_rate: 3.1623e-05
# Epoch 72/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 20.5867 - learning_rate: 3.5481e-05
# Epoch 73/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 21.1238 - learning_rate: 3.9811e-05
# Epoch 74/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 21.5642 - learning_rate: 4.4668e-05
# Epoch 75/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 20.6927 - learning_rate: 5.0119e-05
# Epoch 76/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 23.4772 - learning_rate: 5.6234e-05
# Epoch 77/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 22.5545 - learning_rate: 6.3096e-05
# Epoch 78/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 23.6994 - learning_rate: 7.0795e-05
# Epoch 79/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 21.4715 - learning_rate: 7.9433e-05
# Epoch 80/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step - loss: 21.9625 - learning_rate: 8.9125e-05
# Epoch 81/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 21.5549 - learning_rate: 1.0000e-04
# Epoch 82/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 21.6422 - learning_rate: 1.1220e-04
# Epoch 83/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 23.2736 - learning_rate: 1.2589e-04
# Epoch 84/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 29.3597 - learning_rate: 1.4125e-04
# Epoch 85/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - loss: 23.9956 - learning_rate: 1.5849e-04
# Epoch 86/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 25.3010 - learning_rate: 1.7783e-04
# Epoch 87/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 31.3568 - learning_rate: 1.9953e-04
# Epoch 88/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 37.0889 - learning_rate: 2.2387e-04
# Epoch 89/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 42.3044 - learning_rate: 2.5119e-04
# Epoch 90/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 48.6507 - learning_rate: 2.8184e-04
# Epoch 91/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 49.8441 - learning_rate: 3.1623e-04
# Epoch 92/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 54.8239 - learning_rate: 3.5481e-04
# Epoch 93/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 53.2178 - learning_rate: 3.9811e-04
# Epoch 94/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - loss: 54.0172 - learning_rate: 4.4668e-04
# Epoch 95/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 59.7677 - learning_rate: 5.0119e-04
# Epoch 96/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 60.1710 - learning_rate: 5.6234e-04
# Epoch 97/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 58.5137 - learning_rate: 6.3096e-04
# Epoch 98/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 62.5993 - learning_rate: 7.0795e-04
# Epoch 99/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 60.3433 - learning_rate: 7.9433e-04
# Epoch 100/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 60.2210 - learning_rate: 8.9125e-04

# %%
# Оқу жылдамдығының массивін анықтау
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Фигураның өлшемін орнату
plt.figure(figsize=(10, 6))

# Торды орнату
plt.grid(True)

# Логарифмдік масштабта жоғалту мәнін графиктеу
plt.semilogx(lrs, history.history["loss"])

# Тик белгішелерінің өлшемін ұлғайту
plt.tick_params('both', length=10, width=1, which='both')

# Графиктің шекараларын орнату
plt.axis([1e-8, 1e-3, 0, 100])
# Out:
# (1e-08, 0.001, 0.0, 100.0)

# %% [markdown]
# ## Үлгіні жаттықтыру
#
# Енді үлгіні қалпына келтіруге және үйретуге болады. Ол төмендегі ұяшықта 100 дәуірге орнатылған, бірақ қаласаңыз, оны көбейтуге болады.

# %%
# Keras жасаған күйді қалпына келтіру
tf.keras.backend.clear_session()

# Салмақтарды қалпына келтіру
model.set_weights(init_weights)

# %%
# Оқу жылдамдығын орнату
learning_rate = 8e-7

# Оптимизаторды орнату
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Оқыту параметрлерін орнату
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# %%
# Модельді оқыту
history = model.fit(train_set, epochs=100)
# Out:
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 13s 63ms/step - loss: 60.3013 - mae: 60.7988
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 29.1724 - mae: 29.6653
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - loss: 23.6988 - mae: 24.1920
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 22.0033 - mae: 22.4957
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 20.8325 - mae: 21.3275
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - loss: 20.0447 - mae: 20.5399
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 19.9705 - mae: 20.4650
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 19.3493 - mae: 19.8422
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - loss: 19.4089 - mae: 19.8997
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 19.2327 - mae: 19.7271
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 19.0648 - mae: 19.5587
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 18.9651 - mae: 19.4601
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 19.0175 - mae: 19.5092
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 18.8562 - mae: 19.3479
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 18.7139 - mae: 19.2074
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 18.5946 - mae: 19.0858
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 18.5615 - mae: 19.0541
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 18.4343 - mae: 18.9270
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 18.3313 - mae: 18.8238
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step - loss: 18.3175 - mae: 18.8099
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 18.2690 - mae: 18.7608
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 18.2748 - mae: 18.7661
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - loss: 18.1482 - mae: 18.6404
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - loss: 18.1286 - mae: 18.6207
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 9s 92ms/step - loss: 18.1274 - mae: 18.6205
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 18.0063 - mae: 18.4977
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 17.7702 - mae: 18.2614
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 17.7525 - mae: 18.2444
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 17.8126 - mae: 18.3034
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 17.6875 - mae: 18.1794
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 17.7430 - mae: 18.2338
# Epoch 32/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 17.6063 - mae: 18.0984
# Epoch 33/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 17.5041 - mae: 17.9966
# Epoch 34/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 17.4781 - mae: 17.9705
# Epoch 35/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 17.5264 - mae: 18.0204
# Epoch 36/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 17.4073 - mae: 17.8999
# Epoch 37/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 17.5194 - mae: 18.0113
# Epoch 38/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 17.4253 - mae: 17.9167
# Epoch 39/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 17.3331 - mae: 17.8248
# Epoch 40/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 17.3826 - mae: 17.8735
# Epoch 41/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 17.3337 - mae: 17.8262
# Epoch 42/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 17.2953 - mae: 17.7866
# Epoch 43/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 17.2582 - mae: 17.7501
# Epoch 44/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - loss: 17.3419 - mae: 17.8337
# Epoch 45/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 17.3083 - mae: 17.7993
# Epoch 46/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 17.2199 - mae: 17.7118
# Epoch 47/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 17.3256 - mae: 17.8175
# Epoch 48/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 17.2350 - mae: 17.7256
# Epoch 49/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 17.2865 - mae: 17.7782
# Epoch 50/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 17.2590 - mae: 17.7508
# Epoch 51/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 17.1844 - mae: 17.6757
# Epoch 52/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 17.2868 - mae: 17.7785
# Epoch 53/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 17.1639 - mae: 17.6555
# Epoch 54/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 17.3637 - mae: 17.8541
# Epoch 55/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 17.1325 - mae: 17.6231
# Epoch 56/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 17.1627 - mae: 17.6531
# Epoch 57/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 17.2731 - mae: 17.7644
# Epoch 58/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 17.1818 - mae: 17.6718
# Epoch 59/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 17.1036 - mae: 17.5935
# Epoch 60/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - loss: 17.1585 - mae: 17.6487
# Epoch 61/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 17.2673 - mae: 17.7561
# Epoch 62/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 17.1254 - mae: 17.6164
# Epoch 63/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 17.2456 - mae: 17.7345
# Epoch 64/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 17.2219 - mae: 17.7119
# Epoch 65/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 17.2610 - mae: 17.7501
# Epoch 66/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 17.0999 - mae: 17.5880
# Epoch 67/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 17.1448 - mae: 17.6354
# Epoch 68/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 17.1834 - mae: 17.6750
# Epoch 69/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 17.1111 - mae: 17.6024
# Epoch 70/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 17.2525 - mae: 17.7418
# Epoch 71/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 17.0714 - mae: 17.5635
# Epoch 72/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 17.1403 - mae: 17.6301
# Epoch 73/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 17.1476 - mae: 17.6364
# Epoch 74/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 17.0707 - mae: 17.5594
# Epoch 75/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 17.0520 - mae: 17.5413
# Epoch 76/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 17.0286 - mae: 17.5176
# Epoch 77/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 17.0780 - mae: 17.5673
# Epoch 78/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 17.0665 - mae: 17.5567
# Epoch 79/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 17.0638 - mae: 17.5527
# Epoch 80/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 16.9504 - mae: 17.4401
# Epoch 81/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 17.0621 - mae: 17.5513
# Epoch 82/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 16.9913 - mae: 17.4821
# Epoch 83/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 16.9727 - mae: 17.4628
# Epoch 84/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 17.0424 - mae: 17.5321
# Epoch 85/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 17.0254 - mae: 17.5144
# Epoch 86/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 16.9915 - mae: 17.4826
# Epoch 87/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 16.9278 - mae: 17.4177
# Epoch 88/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 16.8969 - mae: 17.3873
# Epoch 89/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - loss: 16.9657 - mae: 17.4563
# Epoch 90/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 16.9607 - mae: 17.4501
# Epoch 91/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 16.9321 - mae: 17.4215
# Epoch 92/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 16.9276 - mae: 17.4162
# Epoch 93/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 16.9005 - mae: 17.3910
# Epoch 94/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 16.9295 - mae: 17.4209
# Epoch 95/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 16.8936 - mae: 17.3819
# Epoch 96/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 16.8974 - mae: 17.3861
# Epoch 97/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 16.9193 - mae: 17.4107
# Epoch 98/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 16.8440 - mae: 17.3334
# Epoch 99/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 16.8899 - mae: 17.3823
# Epoch 100/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 16.8727 - mae: 17.3638

# %% [markdown]
# Сіз жаттығуды визуализациялай аласыз және жоғалту мен MAE әлі де төмендейтінін көре аласыз.

# %%
# Тарих жазбасынан mae және loss мәндерін алу
mae = history.history['mae']
loss = history.history['loss']

# Эпохалардың санын алу
epochs = range(len(loss))

# mae және loss графигін салу
plot_series(
    x=epochs,
    y=(mae, loss),
    title='MAE және Loss',
    xlabel='Эпоха',
    ylabel='Loss',
    legend=['MAE', 'Loss']
)

# Тек соңғы 80% эпохаларды графиктеу
zoom_split = int(epochs[-1] * 0.2)
epochs_zoom = epochs[zoom_split:]
mae_zoom = mae[zoom_split:]
loss_zoom = loss[zoom_split:]

# Үлкейтілген mae және loss графигін салу
plot_series(
    x=epochs_zoom,
    y=(mae_zoom, loss_zoom),
    title='MAE және Loss',
    xlabel='Эпоха',
    ylabel='Loss',
    legend=['MAE', 'Loss']
)

# %% [markdown]
# ## Модель болжауы
#
# Алдыңғыдай, валидациялық жиынтықтың уақыт диапазоны бойынша болжамдарды алып, метрикаларды есептей аласыз.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Модельді қолданып, деректер терезелеріндегі болжамдарды генерациялайды

    Параметрлер:
      model (TF Keras Model) - деректер терезелерін қабылдайтын модель
      series (float сандар массиві) - уақыттық қатардың мәндерін қамтиды
      window_size (бүтін сан) - терезеге енгізілетін уақыт қадамдарының саны
      batch_size (бүтін сан) - пакет көлемі

    Қайтарады:
      forecast (numpy массиві) - болжамдарды қамтитын массив
    """

    # RNN қабаттарының ерекшелік өлшемі үшін қосымша ось қосу
    series = tf.expand_dims(series, axis=-1)

    # Серия мәндерінен TF деректер жиынтығын жасау
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Деректерді терезеге бөлу, тек көрсетілген өлшемдегі терезелерді таңдау
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Терезелерді бір пакетке біріктіру арқылы тегістеу
    dataset = dataset.flat_map(lambda w: w.batch(window_size))

    # Терезелердің пакеттерін жасау және алдын ала жүктеу
    dataset = dataset.batch(batch_size).prefetch(1)

    # Барлық деректер жиынтығына болжам алу
    forecast = model.predict(dataset, verbose=0)

    return forecast

# %%
# Түпнұсқа қатарды қысқарту
forecast_series = series[split_time-window_size:-1]

# Болжамдарды генерациялау үшін көмекші функцияны қолдану
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Бірөлшемді осьті алып тастау
results = forecast.squeeze()

# Нәтижелерді графиктеу
plot_series(time_valid, (x_valid, results))

# %%
# Compute the MAE
print(tf.keras.metrics.mae(x_valid, results).numpy())
# Out:
# 15.141081

# %% [markdown]
# ## Тапсырма
#
# Уақыт қатарларының деректер жинағын желіден табыңыз немесе оны өзіңіз талдай аласыз, берілген үлгіні пайдаланып уақыт қатарының болжамын жасаңыз
